# %% [markdown]
# This script illustrates the use of Neural Networks for classification tasks and compare their efficacy vs. those of tree-based methods such as Random Forest & Boosting.
#
# The subject data set concerns reading sensor signals from mobile phones to classify 6 types of human activities:
#
# 1. **Walking**,
# 2. **Walking Upstairs**,
# 3. **Walking Downstairs**,
# 4. **Sitting**,
# 5. **Standing**, and
# 6. **Laying**

# %% [markdown]
# # Technical Dependencies
#
# Note that this script requires the following to be installed:
#
# - **`theano`**
# - **`bokeh`**: you also need to start the `bokeh` visualization server by opening a new command-line terminal and run:
#     - **`bokeh-server --backend=memory`**

# %% [markdown]
# # _import modules:_

# %%
# enable In-Line MatPlotLib
# %matplotlib inline

# %%
# Imports from Python v3
from __future__ import division, print_function

# Generic imports
from multiprocessing import cpu_count
from os import system
from pandas import get_dummies
from random import seed
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

# Keras imports
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam, Adadelta, RMSprop, SGD

# Imports from other modules in same folder
from ParseData import parse_human_activity_recog_data

# Imports from Helpy package
system('pip install --upgrade git+git://GitHub.com/ChicagoBoothML/Helpy --no-dependencies')
from ChicagoBoothML_Helpy.KerasTrainingMonitor import NeuralNetworkTrainingMonitor
from ChicagoBoothML_Helpy.Print import printflush

# Seed the randomizer
RANDOM_SEED = 99
seed(RANDOM_SEED)
# Out:
# Using gpu device 0: GeForce GT 750M

# %% [markdown]
# # import UCI Human Activity Recognition data set

# %%
data = parse_human_activity_recog_data()

data.keys()
# Out:
# Parsing Data Set "UCI Human Activity Recognition Using Smartphones"...
#    Parsing Unique Input Features' (X's) Names... done!
#    Parsing Train & Test Input Feature Data Sets... done!
#    Removing Input Feature Data Rows with Missing (NaN) Values... done!
#    Parsing Train & Test Labels (y)... done!
# ['X_test', 'X_train', 'y_train', 'y_test']

# %%
X_train = data['X_train']
y_train = data['y_train']
y_train_binary = get_dummies(y_train)

X_test = data['X_test']
y_test = data['y_test']
y_test_binary = get_dummies(y_test)

# Get some basic counts on the data sets
nb_X_features = len(X_train.columns)
nb_train_samples = len(X_train)
nb_test_samples = len(X_test)
printflush('No. of Input Features X = %s' % '{:,}'.format(nb_X_features))
printflush('No. of Train Samples = %s' % '{:,}'.format(nb_train_samples))
printflush('No. of Test Samples = %s' % '{:,}'.format(nb_test_samples))
# Out:
# No. of Input Features X = 477
# No. of Train Samples = 7,352
# No. of Test Samples = 2,947

# %% [markdown]
# Just to ensure we don't have a missing data problem:

# %%
for x_var_name in X_train:
    printflush(
        '%s: %s type, %i missing'
        % (x_var_name, X_train[x_var_name].dtype, X_train[x_var_name].isnull().sum()))
# Out:
# angle(X,gravityMean): float64 type, 0 missing
# angle(Y,gravityMean): float64 type, 0 missing
# angle(Z,gravityMean): float64 type, 0 missing
# angle(tBodyAccJerkMean),gravityMean): float64 type, 0 missing
# angle(tBodyAccMean,gravity): float64 type, 0 missing
# angle(tBodyGyroJerkMean,gravityMean): float64 type, 0 missing
# angle(tBodyGyroMean,gravityMean): float64 type, 0 missing
# fBodyAcc-bandsEnergy()-1,16: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-1,24: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-1,8: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-17,24: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-17,32: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-25,32: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-25,48: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-33,40: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-33,48: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-41,48: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-49,56: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-49,64: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-57,64: float64 type, 0 missing
# fBodyAcc-bandsEnergy()-9,16: float64 type, 0 missing
# fBodyAcc-energy()-X: float64 type, 0 missing
# fBodyAcc-energy()-Y: float64 type, 0 missing
# fBodyAcc-energy()-Z: float64 type, 0 missing
# fBodyAcc-entropy()-X: float64 type, 0 missing
# fBodyAcc-entropy()-Y: float64 type, 0 missing
# fBodyAcc-entropy()-Z: float64 type, 0 missing
# fBodyAcc-iqr()-X: float64 type, 0 missing
# fBodyAcc-iqr()-Y: float64 type, 0 missing
# fBodyAcc-iqr()-Z: float64 type, 0 missing
# fBodyAcc-kurtosis()-X: float64 type, 0 missing
# fBodyAcc-kurtosis()-Y: float64 type, 0 missing
# fBodyAcc-kurtosis()-Z: float64 type, 0 missing
# fBodyAcc-mad()-X: float64 type, 0 missing
# fBodyAcc-mad()-Y: float64 type, 0 missing
# fBodyAcc-mad()-Z: float64 type, 0 missing
# fBodyAcc-max()-X: float64 type, 0 missing
# fBodyAcc-max()-Y: float64 type, 0 missing
# fBodyAcc-max()-Z: float64 type, 0 missing
# fBodyAcc-maxInds-X: float64 type, 0 missing
# fBodyAcc-maxInds-Y: float64 type, 0 missing
# fBodyAcc-maxInds-Z: float64 type, 0 missing
# fBodyAcc-mean()-X: float64 type, 0 missing
# fBodyAcc-mean()-Y: float64 type, 0 missing
# fBodyAcc-mean()-Z: float64 type, 0 missing
# fBodyAcc-meanFreq()-X: float64 type, 0 missing
# fBodyAcc-meanFreq()-Y: float64 type, 0 missing
# fBodyAcc-meanFreq()-Z: float64 type, 0 missing
# fBodyAcc-min()-X: float64 type, 0 missing
# fBodyAcc-min()-Y: float64 type, 0 missing
# fBodyAcc-min()-Z: float64 type, 0 missing
# fBodyAcc-skewness()-X: float64 type, 0 missing
# fBodyAcc-skewness()-Y: float64 type, 0 missing
# fBodyAcc-skewness()-Z: float64 type, 0 missing
# fBodyAcc-sma(): float64 type, 0 missing
# fBodyAcc-std()-X: float64 type, 0 missing
# fBodyAcc-std()-Y: float64 type, 0 missing
# fBodyAcc-std()-Z: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-1,16: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-1,24: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-1,8: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-17,24: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-17,32: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-25,32: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-25,48: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-33,40: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-33,48: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-41,48: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-49,56: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-49,64: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-57,64: float64 type, 0 missing
# fBodyAccJerk-bandsEnergy()-9,16: float64 type, 0 missing
# fBodyAccJerk-energy()-X: float64 type, 0 missing
# fBodyAccJerk-energy()-Y: float64 type, 0 missing
# fBodyAccJerk-energy()-Z: float64 type, 0 missing
# fBodyAccJerk-entropy()-X: float64 type, 0 missing
# fBodyAccJerk-entropy()-Y: float64 type, 0 missing
# fBodyAccJerk-entropy()-Z: float64 type, 0 missing
# fBodyAccJerk-iqr()-X: float64 type, 0 missing
# fBodyAccJerk-iqr()-Y: float64 type, 0 missing
# fBodyAccJerk-iqr()-Z: float64 type, 0 missing
# fBodyAccJerk-kurtosis()-X: float64 type, 0 missing
# fBodyAccJerk-kurtosis()-Y: float64 type, 0 missing
# fBodyAccJerk-kurtosis()-Z: float64 type, 0 missing
# fBodyAccJerk-mad()-X: float64 type, 0 missing
# fBodyAccJerk-mad()-Y: float64 type, 0 missing
# fBodyAccJerk-mad()-Z: float64 type, 0 missing
# fBodyAccJerk-max()-X: float64 type, 0 missing
# fBodyAccJerk-max()-Y: float64 type, 0 missing
# fBodyAccJerk-max()-Z: float64 type, 0 missing
# fBodyAccJerk-maxInds-X: float64 type, 0 missing
# fBodyAccJerk-maxInds-Y: float64 type, 0 missing
# fBodyAccJerk-maxInds-Z: float64 type, 0 missing
# fBodyAccJerk-mean()-X: float64 type, 0 missing
# fBodyAccJerk-mean()-Y: float64 type, 0 missing
# fBodyAccJerk-mean()-Z: float64 type, 0 missing
# fBodyAccJerk-meanFreq()-X: float64 type, 0 missing
# fBodyAccJerk-meanFreq()-Y: float64 type, 0 missing
# fBodyAccJerk-meanFreq()-Z: float64 type, 0 missing
# fBodyAccJerk-min()-X: float64 type, 0 missing
# fBodyAccJerk-min()-Y: float64 type, 0 missing
# fBodyAccJerk-min()-Z: float64 type, 0 missing
# fBodyAccJerk-skewness()-X: float64 type, 0 missing
# fBodyAccJerk-skewness()-Y: float64 type, 0 missing
# fBodyAccJerk-skewness()-Z: float64 type, 0 missing
# fBodyAccJerk-sma(): float64 type, 0 missing
# fBodyAccJerk-std()-X: float64 type, 0 missing
# fBodyAccJerk-std()-Y: float64 type, 0 missing
# fBodyAccJerk-std()-Z: float64 type, 0 missing
# fBodyAccMag-energy(): float64 type, 0 missing
# fBodyAccMag-entropy(): float64 type, 0 missing
# fBodyAccMag-iqr(): float64 type, 0 missing
# fBodyAccMag-kurtosis(): float64 type, 0 missing
# fBodyAccMag-mad(): float64 type, 0 missing
# fBodyAccMag-max(): float64 type, 0 missing
# fBodyAccMag-maxInds: float64 type, 0 missing
# fBodyAccMag-mean(): float64 type, 0 missing
# fBodyAccMag-meanFreq(): float64 type, 0 missing
# fBodyAccMag-min(): float64 type, 0 missing
# fBodyAccMag-skewness(): float64 type, 0 missing
# fBodyAccMag-sma(): float64 type, 0 missing
# fBodyAccMag-std(): float64 type, 0 missing
# fBodyBodyAccJerkMag-energy(): float64 type, 0 missing
# fBodyBodyAccJerkMag-entropy(): float64 type, 0 missing
# fBodyBodyAccJerkMag-iqr(): float64 type, 0 missing
# fBodyBodyAccJerkMag-kurtosis(): float64 type, 0 missing
# fBodyBodyAccJerkMag-mad(): float64 type, 0 missing
# fBodyBodyAccJerkMag-max(): float64 type, 0 missing
# fBodyBodyAccJerkMag-maxInds: float64 type, 0 missing
# fBodyBodyAccJerkMag-mean(): float64 type, 0 missing
# fBodyBodyAccJerkMag-meanFreq(): float64 type, 0 missing
# fBodyBodyAccJerkMag-min(): float64 type, 0 missing
# fBodyBodyAccJerkMag-skewness(): float64 type, 0 missing
# fBodyBodyAccJerkMag-sma(): float64 type, 0 missing
# fBodyBodyAccJerkMag-std(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-energy(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-entropy(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-iqr(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-kurtosis(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-mad(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-max(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-maxInds: float64 type, 0 missing
# fBodyBodyGyroJerkMag-mean(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-meanFreq(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-min(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-skewness(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-sma(): float64 type, 0 missing
# fBodyBodyGyroJerkMag-std(): float64 type, 0 missing
# fBodyBodyGyroMag-energy(): float64 type, 0 missing
# fBodyBodyGyroMag-entropy(): float64 type, 0 missing
# fBodyBodyGyroMag-iqr(): float64 type, 0 missing
# fBodyBodyGyroMag-kurtosis(): float64 type, 0 missing
# fBodyBodyGyroMag-mad(): float64 type, 0 missing
# fBodyBodyGyroMag-max(): float64 type, 0 missing
# fBodyBodyGyroMag-maxInds: float64 type, 0 missing
# fBodyBodyGyroMag-mean(): float64 type, 0 missing
# fBodyBodyGyroMag-meanFreq(): float64 type, 0 missing
# fBodyBodyGyroMag-min(): float64 type, 0 missing
# fBodyBodyGyroMag-skewness(): float64 type, 0 missing
# fBodyBodyGyroMag-sma(): float64 type, 0 missing
# fBodyBodyGyroMag-std(): float64 type, 0 missing
# fBodyGyro-bandsEnergy()-1,16: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-1,24: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-1,8: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-17,24: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-17,32: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-25,32: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-25,48: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-33,40: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-33,48: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-41,48: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-49,56: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-49,64: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-57,64: float64 type, 0 missing
# fBodyGyro-bandsEnergy()-9,16: float64 type, 0 missing
# fBodyGyro-energy()-X: float64 type, 0 missing
# fBodyGyro-energy()-Y: float64 type, 0 missing
# fBodyGyro-energy()-Z: float64 type, 0 missing
# fBodyGyro-entropy()-X: float64 type, 0 missing
# fBodyGyro-entropy()-Y: float64 type, 0 missing
# fBodyGyro-entropy()-Z: float64 type, 0 missing
# fBodyGyro-iqr()-X: float64 type, 0 missing
# fBodyGyro-iqr()-Y: float64 type, 0 missing
# fBodyGyro-iqr()-Z: float64 type, 0 missing
# fBodyGyro-kurtosis()-X: float64 type, 0 missing
# fBodyGyro-kurtosis()-Y: float64 type, 0 missing
# fBodyGyro-kurtosis()-Z: float64 type, 0 missing
# fBodyGyro-mad()-X: float64 type, 0 missing
# fBodyGyro-mad()-Y: float64 type, 0 missing
# fBodyGyro-mad()-Z: float64 type, 0 missing
# fBodyGyro-max()-X: float64 type, 0 missing
# fBodyGyro-max()-Y: float64 type, 0 missing
# fBodyGyro-max()-Z: float64 type, 0 missing
# fBodyGyro-maxInds-X: float64 type, 0 missing
# fBodyGyro-maxInds-Y: float64 type, 0 missing
# fBodyGyro-maxInds-Z: float64 type, 0 missing
# fBodyGyro-mean()-X: float64 type, 0 missing
# fBodyGyro-mean()-Y: float64 type, 0 missing
# fBodyGyro-mean()-Z: float64 type, 0 missing
# fBodyGyro-meanFreq()-X: float64 type, 0 missing
# fBodyGyro-meanFreq()-Y: float64 type, 0 missing
# fBodyGyro-meanFreq()-Z: float64 type, 0 missing
# fBodyGyro-min()-X: float64 type, 0 missing
# fBodyGyro-min()-Y: float64 type, 0 missing
# fBodyGyro-min()-Z: float64 type, 0 missing
# fBodyGyro-skewness()-X: float64 type, 0 missing
# fBodyGyro-skewness()-Y: float64 type, 0 missing
# fBodyGyro-skewness()-Z: float64 type, 0 missing
# fBodyGyro-sma(): float64 type, 0 missing
# fBodyGyro-std()-X: float64 type, 0 missing
# fBodyGyro-std()-Y: float64 type, 0 missing
# fBodyGyro-std()-Z: float64 type, 0 missing
# tBodyAcc-arCoeff()-X,1: float64 type, 0 missing
# tBodyAcc-arCoeff()-X,2: float64 type, 0 missing
# tBodyAcc-arCoeff()-X,3: float64 type, 0 missing
# tBodyAcc-arCoeff()-X,4: float64 type, 0 missing
# tBodyAcc-arCoeff()-Y,1: float64 type, 0 missing
# tBodyAcc-arCoeff()-Y,2: float64 type, 0 missing
# tBodyAcc-arCoeff()-Y,3: float64 type, 0 missing
# tBodyAcc-arCoeff()-Y,4: float64 type, 0 missing
# tBodyAcc-arCoeff()-Z,1: float64 type, 0 missing
# tBodyAcc-arCoeff()-Z,2: float64 type, 0 missing
# tBodyAcc-arCoeff()-Z,3: float64 type, 0 missing
# tBodyAcc-arCoeff()-Z,4: float64 type, 0 missing
# tBodyAcc-correlation()-X,Y: float64 type, 0 missing
# tBodyAcc-correlation()-X,Z: float64 type, 0 missing
# tBodyAcc-correlation()-Y,Z: float64 type, 0 missing
# tBodyAcc-energy()-X: float64 type, 0 missing
# tBodyAcc-energy()-Y: float64 type, 0 missing
# tBodyAcc-energy()-Z: float64 type, 0 missing
# tBodyAcc-entropy()-X: float64 type, 0 missing
# tBodyAcc-entropy()-Y: float64 type, 0 missing
# tBodyAcc-entropy()-Z: float64 type, 0 missing
# tBodyAcc-iqr()-X: float64 type, 0 missing
# tBodyAcc-iqr()-Y: float64 type, 0 missing
# tBodyAcc-iqr()-Z: float64 type, 0 missing
# tBodyAcc-mad()-X: float64 type, 0 missing
# tBodyAcc-mad()-Y: float64 type, 0 missing
# tBodyAcc-mad()-Z: float64 type, 0 missing
# tBodyAcc-max()-X: float64 type, 0 missing
# tBodyAcc-max()-Y: float64 type, 0 missing
# tBodyAcc-max()-Z: float64 type, 0 missing
# tBodyAcc-mean()-X: float64 type, 0 missing
# tBodyAcc-mean()-Y: float64 type, 0 missing
# tBodyAcc-mean()-Z: float64 type, 0 missing
# tBodyAcc-min()-X: float64 type, 0 missing
# tBodyAcc-min()-Y: float64 type, 0 missing
# tBodyAcc-min()-Z: float64 type, 0 missing
# tBodyAcc-sma(): float64 type, 0 missing
# tBodyAcc-std()-X: float64 type, 0 missing
# tBodyAcc-std()-Y: float64 type, 0 missing
# tBodyAcc-std()-Z: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-X,1: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-X,2: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-X,3: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-X,4: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Y,1: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Y,2: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Y,3: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Y,4: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Z,1: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Z,2: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Z,3: float64 type, 0 missing
# tBodyAccJerk-arCoeff()-Z,4: float64 type, 0 missing
# tBodyAccJerk-correlation()-X,Y: float64 type, 0 missing
# tBodyAccJerk-correlation()-X,Z: float64 type, 0 missing
# tBodyAccJerk-correlation()-Y,Z: float64 type, 0 missing
# tBodyAccJerk-energy()-X: float64 type, 0 missing
# tBodyAccJerk-energy()-Y: float64 type, 0 missing
# tBodyAccJerk-energy()-Z: float64 type, 0 missing
# tBodyAccJerk-entropy()-X: float64 type, 0 missing
# tBodyAccJerk-entropy()-Y: float64 type, 0 missing
# tBodyAccJerk-entropy()-Z: float64 type, 0 missing
# tBodyAccJerk-iqr()-X: float64 type, 0 missing
# tBodyAccJerk-iqr()-Y: float64 type, 0 missing
# tBodyAccJerk-iqr()-Z: float64 type, 0 missing
# tBodyAccJerk-mad()-X: float64 type, 0 missing
# tBodyAccJerk-mad()-Y: float64 type, 0 missing
# tBodyAccJerk-mad()-Z: float64 type, 0 missing
# tBodyAccJerk-max()-X: float64 type, 0 missing
# tBodyAccJerk-max()-Y: float64 type, 0 missing
# tBodyAccJerk-max()-Z: float64 type, 0 missing
# tBodyAccJerk-mean()-X: float64 type, 0 missing
# tBodyAccJerk-mean()-Y: float64 type, 0 missing
# tBodyAccJerk-mean()-Z: float64 type, 0 missing
# tBodyAccJerk-min()-X: float64 type, 0 missing
# tBodyAccJerk-min()-Y: float64 type, 0 missing
# tBodyAccJerk-min()-Z: float64 type, 0 missing
# tBodyAccJerk-sma(): float64 type, 0 missing
# tBodyAccJerk-std()-X: float64 type, 0 missing
# tBodyAccJerk-std()-Y: float64 type, 0 missing
# tBodyAccJerk-std()-Z: float64 type, 0 missing
# tBodyAccJerkMag-arCoeff()1: float64 type, 0 missing
# tBodyAccJerkMag-arCoeff()2: float64 type, 0 missing
# tBodyAccJerkMag-arCoeff()3: float64 type, 0 missing
# tBodyAccJerkMag-arCoeff()4: float64 type, 0 missing
# tBodyAccJerkMag-energy(): float64 type, 0 missing
# tBodyAccJerkMag-entropy(): float64 type, 0 missing
# tBodyAccJerkMag-iqr(): float64 type, 0 missing
# tBodyAccJerkMag-mad(): float64 type, 0 missing
# tBodyAccJerkMag-max(): float64 type, 0 missing
# tBodyAccJerkMag-mean(): float64 type, 0 missing
# tBodyAccJerkMag-min(): float64 type, 0 missing
# tBodyAccJerkMag-sma(): float64 type, 0 missing
# tBodyAccJerkMag-std(): float64 type, 0 missing
# tBodyAccMag-arCoeff()1: float64 type, 0 missing
# tBodyAccMag-arCoeff()2: float64 type, 0 missing
# tBodyAccMag-arCoeff()3: float64 type, 0 missing
# tBodyAccMag-arCoeff()4: float64 type, 0 missing
# tBodyAccMag-energy(): float64 type, 0 missing
# tBodyAccMag-entropy(): float64 type, 0 missing
# tBodyAccMag-iqr(): float64 type, 0 missing
# tBodyAccMag-mad(): float64 type, 0 missing
# tBodyAccMag-max(): float64 type, 0 missing
# tBodyAccMag-mean(): float64 type, 0 missing
# tBodyAccMag-min(): float64 type, 0 missing
# tBodyAccMag-sma(): float64 type, 0 missing
# tBodyAccMag-std(): float64 type, 0 missing
# tBodyGyro-arCoeff()-X,1: float64 type, 0 missing
# tBodyGyro-arCoeff()-X,2: float64 type, 0 missing
# tBodyGyro-arCoeff()-X,3: float64 type, 0 missing
# tBodyGyro-arCoeff()-X,4: float64 type, 0 missing
# tBodyGyro-arCoeff()-Y,1: float64 type, 0 missing
# tBodyGyro-arCoeff()-Y,2: float64 type, 0 missing
# tBodyGyro-arCoeff()-Y,3: float64 type, 0 missing
# tBodyGyro-arCoeff()-Y,4: float64 type, 0 missing
# tBodyGyro-arCoeff()-Z,1: float64 type, 0 missing
# tBodyGyro-arCoeff()-Z,2: float64 type, 0 missing
# tBodyGyro-arCoeff()-Z,3: float64 type, 0 missing
# tBodyGyro-arCoeff()-Z,4: float64 type, 0 missing
# tBodyGyro-correlation()-X,Y: float64 type, 0 missing
# tBodyGyro-correlation()-X,Z: float64 type, 0 missing
# tBodyGyro-correlation()-Y,Z: float64 type, 0 missing
# tBodyGyro-energy()-X: float64 type, 0 missing
# tBodyGyro-energy()-Y: float64 type, 0 missing
# tBodyGyro-energy()-Z: float64 type, 0 missing
# tBodyGyro-entropy()-X: float64 type, 0 missing
# tBodyGyro-entropy()-Y: float64 type, 0 missing
# tBodyGyro-entropy()-Z: float64 type, 0 missing
# tBodyGyro-iqr()-X: float64 type, 0 missing
# tBodyGyro-iqr()-Y: float64 type, 0 missing
# tBodyGyro-iqr()-Z: float64 type, 0 missing
# tBodyGyro-mad()-X: float64 type, 0 missing
# tBodyGyro-mad()-Y: float64 type, 0 missing
# tBodyGyro-mad()-Z: float64 type, 0 missing
# tBodyGyro-max()-X: float64 type, 0 missing
# tBodyGyro-max()-Y: float64 type, 0 missing
# tBodyGyro-max()-Z: float64 type, 0 missing
# tBodyGyro-mean()-X: float64 type, 0 missing
# tBodyGyro-mean()-Y: float64 type, 0 missing
# tBodyGyro-mean()-Z: float64 type, 0 missing
# tBodyGyro-min()-X: float64 type, 0 missing
# tBodyGyro-min()-Y: float64 type, 0 missing
# tBodyGyro-min()-Z: float64 type, 0 missing
# tBodyGyro-sma(): float64 type, 0 missing
# tBodyGyro-std()-X: float64 type, 0 missing
# tBodyGyro-std()-Y: float64 type, 0 missing
# tBodyGyro-std()-Z: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-X,1: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-X,2: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-X,3: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-X,4: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Y,1: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Y,2: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Y,3: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Y,4: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Z,1: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Z,2: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Z,3: float64 type, 0 missing
# tBodyGyroJerk-arCoeff()-Z,4: float64 type, 0 missing
# tBodyGyroJerk-correlation()-X,Y: float64 type, 0 missing
# tBodyGyroJerk-correlation()-X,Z: float64 type, 0 missing
# tBodyGyroJerk-correlation()-Y,Z: float64 type, 0 missing
# tBodyGyroJerk-energy()-X: float64 type, 0 missing
# tBodyGyroJerk-energy()-Y: float64 type, 0 missing
# tBodyGyroJerk-energy()-Z: float64 type, 0 missing
# tBodyGyroJerk-entropy()-X: float64 type, 0 missing
# tBodyGyroJerk-entropy()-Y: float64 type, 0 missing
# tBodyGyroJerk-entropy()-Z: float64 type, 0 missing
# tBodyGyroJerk-iqr()-X: float64 type, 0 missing
# tBodyGyroJerk-iqr()-Y: float64 type, 0 missing
# tBodyGyroJerk-iqr()-Z: float64 type, 0 missing
# tBodyGyroJerk-mad()-X: float64 type, 0 missing
# tBodyGyroJerk-mad()-Y: float64 type, 0 missing
# tBodyGyroJerk-mad()-Z: float64 type, 0 missing
# tBodyGyroJerk-max()-X: float64 type, 0 missing
# tBodyGyroJerk-max()-Y: float64 type, 0 missing
# tBodyGyroJerk-max()-Z: float64 type, 0 missing
# tBodyGyroJerk-mean()-X: float64 type, 0 missing
# tBodyGyroJerk-mean()-Y: float64 type, 0 missing
# tBodyGyroJerk-mean()-Z: float64 type, 0 missing
# tBodyGyroJerk-min()-X: float64 type, 0 missing
# tBodyGyroJerk-min()-Y: float64 type, 0 missing
# tBodyGyroJerk-min()-Z: float64 type, 0 missing
# tBodyGyroJerk-sma(): float64 type, 0 missing
# tBodyGyroJerk-std()-X: float64 type, 0 missing
# tBodyGyroJerk-std()-Y: float64 type, 0 missing
# tBodyGyroJerk-std()-Z: float64 type, 0 missing
# tBodyGyroJerkMag-arCoeff()1: float64 type, 0 missing
# tBodyGyroJerkMag-arCoeff()2: float64 type, 0 missing
# tBodyGyroJerkMag-arCoeff()3: float64 type, 0 missing
# tBodyGyroJerkMag-arCoeff()4: float64 type, 0 missing
# tBodyGyroJerkMag-energy(): float64 type, 0 missing
# tBodyGyroJerkMag-entropy(): float64 type, 0 missing
# tBodyGyroJerkMag-iqr(): float64 type, 0 missing
# tBodyGyroJerkMag-mad(): float64 type, 0 missing
# tBodyGyroJerkMag-max(): float64 type, 0 missing
# tBodyGyroJerkMag-mean(): float64 type, 0 missing
# tBodyGyroJerkMag-min(): float64 type, 0 missing
# tBodyGyroJerkMag-sma(): float64 type, 0 missing
# tBodyGyroJerkMag-std(): float64 type, 0 missing
# tBodyGyroMag-arCoeff()1: float64 type, 0 missing
# tBodyGyroMag-arCoeff()2: float64 type, 0 missing
# tBodyGyroMag-arCoeff()3: float64 type, 0 missing
# tBodyGyroMag-arCoeff()4: float64 type, 0 missing
# tBodyGyroMag-energy(): float64 type, 0 missing
# tBodyGyroMag-entropy(): float64 type, 0 missing
# tBodyGyroMag-iqr(): float64 type, 0 missing
# tBodyGyroMag-mad(): float64 type, 0 missing
# tBodyGyroMag-max(): float64 type, 0 missing
# tBodyGyroMag-mean(): float64 type, 0 missing
# tBodyGyroMag-min(): float64 type, 0 missing
# tBodyGyroMag-sma(): float64 type, 0 missing
# tBodyGyroMag-std(): float64 type, 0 missing
# tGravityAcc-arCoeff()-X,1: float64 type, 0 missing
# tGravityAcc-arCoeff()-X,2: float64 type, 0 missing
# tGravityAcc-arCoeff()-X,3: float64 type, 0 missing
# tGravityAcc-arCoeff()-X,4: float64 type, 0 missing
# tGravityAcc-arCoeff()-Y,1: float64 type, 0 missing
# tGravityAcc-arCoeff()-Y,2: float64 type, 0 missing
# tGravityAcc-arCoeff()-Y,3: float64 type, 0 missing
# tGravityAcc-arCoeff()-Y,4: float64 type, 0 missing
# tGravityAcc-arCoeff()-Z,1: float64 type, 0 missing
# tGravityAcc-arCoeff()-Z,2: float64 type, 0 missing
# tGravityAcc-arCoeff()-Z,3: float64 type, 0 missing
# tGravityAcc-arCoeff()-Z,4: float64 type, 0 missing
# tGravityAcc-correlation()-X,Y: float64 type, 0 missing
# tGravityAcc-correlation()-X,Z: float64 type, 0 missing
# tGravityAcc-correlation()-Y,Z: float64 type, 0 missing
# tGravityAcc-energy()-X: float64 type, 0 missing
# tGravityAcc-energy()-Y: float64 type, 0 missing
# tGravityAcc-energy()-Z: float64 type, 0 missing
# tGravityAcc-entropy()-X: float64 type, 0 missing
# tGravityAcc-entropy()-Y: float64 type, 0 missing
# tGravityAcc-entropy()-Z: float64 type, 0 missing
# tGravityAcc-iqr()-X: float64 type, 0 missing
# tGravityAcc-iqr()-Y: float64 type, 0 missing
# tGravityAcc-iqr()-Z: float64 type, 0 missing
# tGravityAcc-mad()-X: float64 type, 0 missing
# tGravityAcc-mad()-Y: float64 type, 0 missing
# tGravityAcc-mad()-Z: float64 type, 0 missing
# tGravityAcc-max()-X: float64 type, 0 missing
# tGravityAcc-max()-Y: float64 type, 0 missing
# tGravityAcc-max()-Z: float64 type, 0 missing
# tGravityAcc-mean()-X: float64 type, 0 missing
# tGravityAcc-mean()-Y: float64 type, 0 missing
# tGravityAcc-mean()-Z: float64 type, 0 missing
# tGravityAcc-min()-X: float64 type, 0 missing
# tGravityAcc-min()-Y: float64 type, 0 missing
# tGravityAcc-min()-Z: float64 type, 0 missing
# tGravityAcc-sma(): float64 type, 0 missing
# tGravityAcc-std()-X: float64 type, 0 missing
# tGravityAcc-std()-Y: float64 type, 0 missing
# tGravityAcc-std()-Z: float64 type, 0 missing
# tGravityAccMag-arCoeff()1: float64 type, 0 missing
# tGravityAccMag-arCoeff()2: float64 type, 0 missing
# tGravityAccMag-arCoeff()3: float64 type, 0 missing
# tGravityAccMag-arCoeff()4: float64 type, 0 missing
# tGravityAccMag-energy(): float64 type, 0 missing
# tGravityAccMag-entropy(): float64 type, 0 missing
# tGravityAccMag-iqr(): float64 type, 0 missing
# tGravityAccMag-mad(): float64 type, 0 missing
# tGravityAccMag-max(): float64 type, 0 missing
# tGravityAccMag-mean(): float64 type, 0 missing
# tGravityAccMag-min(): float64 type, 0 missing
# tGravityAccMag-sma(): float64 type, 0 missing
# tGravityAccMag-std(): float64 type, 0 missing

# %% [markdown]
# # Neural Network Model

# %%
# Global constants
NB_HUMAN_ACTIVITES = 6
NB_EXAMPLE_FEATURES = 10


# **********************************************************************************************************************
# *** USER-ADJUSTABLE GLOBAL CONSTANTS *********************************************************************************
# **********************************************************************************************************************
NB_NEURAL_NETWORK_HIDDEN_UNITS = 300   #default=100

SGD_OPTIMIZER_LEARNING_RATE = .01   # default=.01
SGD_OPTIMIZER_LEARNING_RATE_DECAY_RATE = .0   # default=0, meaning no learning rate decay
SGD_OPTIMIZER_MOMENTUM_RATE = .9   # default=.9; 0 means no momentum
SGD_OPTIMIZER_NESTEROV_MOMENTUM_YESNO = True   # default=True; using Nesterov momentum usually speeds up learning

NB_TRAIN_EPOCHS = 100   # default=100
TRAIN_MINI_BATCH_SIZE = 300   # default=300
VALIDATION_DATA_PROPORTION = .2   # default=.2; this is proportion of Training Data held out for validation
# **********************************************************************************************************************

# %%
printflush('\nCreating Feed-Forward Neural Network (FFNN)... ', end='')

ffnn = Sequential()
ffnn.add(
    Dense(input_dim=nb_X_features,
          output_dim=NB_NEURAL_NETWORK_HIDDEN_UNITS,
          init='uniform'))
ffnn.add(
    Activation('tanh'))
ffnn.add(
    Dense(input_dim=NB_NEURAL_NETWORK_HIDDEN_UNITS,
          output_dim=NB_HUMAN_ACTIVITES,
          init='uniform'))
ffnn.add(Activation('softmax'))

printflush('done!\n')


# Set FFNN's Loss Function & Optimizer
printflush('\nCompiling FFNN with Objective Loss Function & Optimization Method... ', end='')
stochastic_gradient_descent_optimizer = SGD(
    lr=SGD_OPTIMIZER_LEARNING_RATE,
    decay=SGD_OPTIMIZER_LEARNING_RATE_DECAY_RATE,
    momentum=SGD_OPTIMIZER_MOMENTUM_RATE,
    nesterov=SGD_OPTIMIZER_NESTEROV_MOMENTUM_YESNO)
ffnn.compile(
    loss='categorical_crossentropy',
    optimizer=stochastic_gradient_descent_optimizer)
printflush('done!\n')


# Initiate FFNN Training Monitor to keep track of training progress
ffnn_training_history = NeuralNetworkTrainingMonitor(
    plot_title='Neural Network Learning Curves: Human Activity Recognition')


# Train FFNN
ffnn.fit(
    X=X_train.values,
    y=y_train_binary.values,
    nb_epoch=NB_TRAIN_EPOCHS,
    batch_size=TRAIN_MINI_BATCH_SIZE,
    show_accuracy=True,
    validation_split=VALIDATION_DATA_PROPORTION,
    verbose=0,   # no need to log output to the terminal because we already have the live plot
    callbacks=[ffnn_training_history],
    shuffle=True)


# Get the best trained FFNN
ffnn = ffnn_training_history.best_model
# Out:
# Creating Feed-Forward Neural Network (FFNN)... done!
#
#
# Compiling FFNN with Objective Loss Function & Optimization Method... done!
#
#
# Connecting to Bokeh Server for live Learning Curves plotting...
#
# Using saved session configuration for http://localhost:5006/
# To override, pass 'load_from_config=False' to Session
#
# Connecting to Bokeh Server for live Learning Curves plotting... done!
#
#
# FFNN Training Progress
# ______________________
#
# FFNN Training Finished! (1,999 Batches in total)
#
# Best trained FFNN (with lowest Validation Loss) is from epoch #96
# Training Accuracy (approx) = 99.1%, Validation Accuracy = 96.1%

# %%
# Evaluate trained FFNN on Test Data
printflush('\nEvaluating Trained FFNN on Test Data...')
test_evaluation = ffnn.evaluate(
    X=X_test.values,
    y=y_test_binary.values,
    show_accuracy=True,
    verbose=0)
printflush('Test Set Loss = %s' % '{:.3g}'.format(test_evaluation[0]))
printflush('Test Set Accuracy = %s%%' % '{:.2f}'.format(100. * test_evaluation[1]))
# Out:
# Evaluating Trained FFNN on Test Data...
# Test Set Loss = 0.156
# Test Set Accuracy = 94.54%

# %% [markdown]
# # Trees-Based Models
#
# Let's now try out a Random Forest and a Boosted model:

# %%
B = 600

rf_model = RandomForestClassifier(
    n_estimators=B,
    criterion='entropy',
    max_depth=None,   # expand until all leaves are pure or contain < MIN_SAMPLES_SPLIT samples
    min_samples_split=100,
    min_samples_leaf=50,
    min_weight_fraction_leaf=0.0,
    max_features=None,   # number of features to consider when looking for the best split; None: max_features=n_features
    max_leaf_nodes=None,   # None: unlimited number of leaf nodes
    bootstrap=True,
    oob_score=True,   # estimate Out-of-Bag Cross Entropy
    n_jobs=cpu_count() - 2,   # paralellize over all CPU cores but 2
    class_weight=None,    # our classes are skewed, but but too skewed
    random_state=RANDOM_SEED,
    verbose=0,
    warm_start=False)

rf_model.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_samples_leaf=50, min_samples_split=100,
#             min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=6,
#             oob_score=True, random_state=99, verbose=0, warm_start=False)

# %%
# B = 1200

# boost_model = GradientBoostingClassifier(
#     n_estimators=B,
#     loss='deviance',   # a.k.a Cross Entropy in Classification
#     learning_rate=.01,   # shrinkage parameter
#     subsample=1.,
#     min_samples_split=200,
#     min_samples_leaf=100,
#     min_weight_fraction_leaf=0.0,
#     max_depth=10,   # maximum tree depth / number of levels of interaction
#     init=None,
#     random_state=RANDOM_SEED,
#     max_features=None,   # number of features to consider when looking for the best split; None: max_features=n_features
#     verbose=0,
#     max_leaf_nodes=None,   # None: unlimited number of leaf nodes
#     warm_start=False)

# boost_model.fit(X=X_train, y=y_train)

# %% [markdown]
# We'll now evaluate the OOS performances of these 2 models on the Test set:

# %%
rf_pred = rf_model.predict(X=X_test)

rf_oos_accuracy = (rf_pred == y_test).sum() / nb_test_samples

rf_oos_accuracy
# Out:
# 0.88564642008822536

# %%
# boost_pred = boost_model.predict(X=X_test)

# boost_oos_accuracy = (boost_pred == y_test).sum() / nb_test_samples

# boost_oos_accuracy

# %% [markdown]
# We see that with hundreds of X features, it become rather hard and time-consuming to train good trees-based models. Trees would have to go very deep to capture complex variable interactions.
#
# In such cases, Neural Networks can often (but certainly not always) be an efficient way to figure out the interactions and estimate their influences on the predictive outcomes at the same time.
